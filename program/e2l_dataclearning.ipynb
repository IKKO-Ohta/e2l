# %%
import pandas as pd

# %%
import glob
files = glob.glob('*.txt')

# %%
pd.read_csv('TRV.2005-2014.txt',names=('name', 'date', 'time','value','contract','contract_quantity'),delimiter='\t',)
# Out:
#        name      date  time     value  contract  contract_quantity
# 0       TRV  20070227   930   53.1900     18800                  7
# 1       TRV  20070227   931   54.0000      8400                 66
# 2       TRV  20070227   932   54.0000      4300                 35
# 3       TRV  20070227   933   54.0000      3100                 19
# 4       TRV  20070227   934   53.8000      3500                 15
# 5       TRV  20070227   935   53.6400      6700                 23
# 6       TRV  20070227   936   53.6450      8600                 30
# 7       TRV  20070227   937   53.7200      6500                 26
# 8       TRV  20070227   938   53.7100      7900                 36
# 9       TRV  20070227   939   53.7300      6100                 32
# 10      TRV  20070227   940   53.6800     10700                 47
# 11      TRV  20070227   941   53.5800      8900                 27
# 12      TRV  20070227   942   53.4500      3600                 11
# ...

# %%
files
# Out:
# ['AA.2005-2014.txt',
#  'AAPL.O.2005-2014.txt',
#  'AIG.2005-2014.txt',
#  'AXP.2005-2014.txt',
#  'BA.2005-2014.txt',
#  'BAC.2005-2014.txt',
#  'C.2005-2014.txt',
#  'CAT.2005-2014.txt',
#  'CSCO.O.2005-2014.txt',
#  'CVX.2005-2014.txt',
#  'DD.2005-2014.txt',
#  'DIS.2005-2014.txt',
#  'GE.2005-2014.txt',
#  'GM.2005-2014.txt',
#  'GS.2005-2014.txt',
#  'HD.2005-2014.txt',
#  'HON.2005-2014.txt',
#  'HPQ.2005-2014.txt',
#  'IBM.2005-2014.txt',
#  'INTC.O.2005-2014.txt',
#  'JNJ.2005-2014.txt',
#  'JPM.2005-2014.txt',
#  'KO.2005-2014.txt',
#  'MCD.2005-2014.txt',
#  'MMM.2005-2014.txt',
#  'MO.2005-2014.txt',
#  'MRK.2005-2014.txt',
#  'MSFT.O.2005-2014.txt',
#  'NKE.2005-2014.txt',
#  'PFE.2005-2014.txt',
#  'PG.2005-2014.txt',
#  'T.2005-2014.txt',
#  'TRV.2005-2014.txt',
#  'UNH.2005-2014.txt',
#  'UTX.2005-2014.txt',
#  'V.2005-2014.txt',
#  'VZ.2005-2014.txt',
#  'WMT.2005-2014.txt',
#  'XOM.2005-2014.txt']
